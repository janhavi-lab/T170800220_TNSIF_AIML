# %%
print("Hello")
''' Connect collab to drive-> Click Connect
all datatypes in python are bydefault String

'''
#fkfd
# Out:
# Hello
# ' Connect collab to drive-> Click Connect\nall datatypes in python are bydefault String\n\n'

# %% [markdown]
# Datatypes in python- int, str, float, double, boolean

# %%
name = "Riya"
l_name= 'Shah'
print(name + ' ' +l_name)
print(type(name))
# Out:
# Riya Shah
# <class 'str'>

# %%
age=12
abs = True
perc = 78.91
print(type(age))
print(type(abs))
print(type(perc))
print("name is "+ name+ " age is "+ str(age))
# Out:
# <class 'int'>
# <class 'bool'>
# <class 'float'>
# name is Riya age is 12

# %%
print('For boolean: ' + str(abs))
print('For float: ' + str(perc))

# %%
#taking input from user
gender = input("Enter your gender: ")
print(gender)
print(type(gender))
#by default string datatype for int,float,boolean
# Out:
# Enter your gender: female
# female
# <class 'str'>

# %%
num = int(input("Enter your age: "))
print(num)
print(type(num))
# Out:
# Enter your age: 20
# 20
# <class 'int'>

# %% [markdown]
# Operators

# %% [markdown]
# Types- Arithmetic, assignment, logical, bit-wise, comparison.

# %%
#Arithmetic
a=5
b=7
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)
# Out:
# 12
# -2
# 35
# 0.7142857142857143
# 5
# 78125
# 0

# %%
#Comparison
a=6
b=6
print(a>b)
print(a<b)
print(a==b)
print(a>=b)
print(a<=b)
# Out:
# False
# False
# True
# True
# True

# %%
age =19
print(age > 18 or age < 65)
# Out:
# True

# %%
#Asssignment
a = 5
print(a)
a += 5
print(a)
# a = a + 5
a -= 2
print(a)
# Out:
# 5
# 10
# 8

# %%
text = "Pythom"
print("p" in text)  #case-sensitive language
# Out:
# False

# %%
#is == isnot !=
a=10
b=a
print(a is b)
print(a == b)
print(a != b)
print(a is not b)
# Out:
# True
# True
# False
# False

# %%
#Conditional statements
# if, elif, else

a=11
b=10
if(a<b):
  print("Hello")     #tab is must, it is considered as content written in braket
elif(a>b):
  print("Byeeee")
elif(a==b):
  print("Judwa")
else:
  print("Bye")

if (a!=b):
  print("Ram")


#if(only in start)_elif(only in middle)_else(only at end)
# Out:
# Byeeee
# Ram
